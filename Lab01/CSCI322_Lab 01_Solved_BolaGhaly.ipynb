# %% [markdown]
# # Your name: Bola Gerges Saeed Ghaly
# # Section: 3B

# %% [markdown]
# #  **Pandas**

# %%
#connect to drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Read CSV, Crosstab

# %%
# start with pandas
import pandas as pd
import matplotlib as plt

# %%
#read csv file
df = pd.read_csv('/content/drive/MyDrive/Lab1/heart.csv')

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %% [markdown]
# # display records, shapes and data types

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# * **display the last 3 records of the table**

# %%
## your code here
df.tail(3)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %% [markdown]
#  **display the shape and the size of the table**

# %% [markdown]
# * **shape**

# %%
## your code here
df.shape
# Out:
# (303, 14)

# %% [markdown]
# * **size:** total number of cells

# %%
## your code here
df.size
# Out:
# 4242

# %% [markdown]
# * **number of samples in the dataset**

# %%
## your code here
#num of rows
df.shape[0]
# Out:
# 303

# %% [markdown]
# * **print columns names**

# %%
## your code here
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# * **print columns data types**

# %%
## your code here
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# # Selection

# %% [markdown]
# * **select the age column**

# %%
## your code here
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %% [markdown]
# * **select the first 3 rows in the age column**

# %%
## your code here
df['age'].iloc[0:3]
# Out:
# 0    63
# 1    37
# 2    41
# Name: age, dtype: int64

# %%
df['age'].loc[0:2]
# Out:
# 0    63
# 1    37
# 2    41
# Name: age, dtype: int64

# %%
df['age'].head(3)
# Out:
# 0    63
# 1    37
# 2    41
# Name: age, dtype: int64

# %%
df['age'][0:3]
# Out:
# 0    63
# 1    37
# 2    41
# Name: age, dtype: int64

# %% [markdown]
# * **select age, fbs and target columns**

# %%
## your code here
df[['age','fbs','target']]
# Out:
#      age  fbs  target
# 0     63    1       1
# 1     37    0       1
# 2     41    0       1
# 3     56    0       1
# 4     57    0       1
# ..   ...  ...     ...
# 298   57    0       0
# 299   45    0       0
# 300   68    1       0
# 301   57    0       0
# 302   57    0       0
#
# [303 rows x 3 columns]

# %% [markdown]
# * **select age, fbs and target columns and rows from 10 to 15:** use both loc and iloc

# %%
## your code here #use loc
df.loc[10:15,['age', 'fbs', 'target']]
# Out:
#     age  fbs  target
# 10   54    0       1
# 11   48    0       1
# 12   49    0       1
# 13   64    0       1
# 14   58    1       1
# 15   50    0       1

# %%
## your code here #use iloc  columns: 0, 5, 13
df.iloc[10:15,[0, 5, 13]]
# Out:
#     age  fbs  target
# 10   54    0       1
# 11   48    0       1
# 12   49    0       1
# 13   64    0       1
# 14   58    1       1

# %%
#not to get confused we can use either df[['age','fbs','target']].loc[10:15] or df[['age','fbs','target']].iloc[10:16] paying attention to rows indices
print(df[['age','fbs','target']].loc[10:15] == df[['age','fbs','target']].iloc[10:16])
# Out:
#      age   fbs  target
# 10  True  True    True
# 11  True  True    True
# 12  True  True    True
# 13  True  True    True
# 14  True  True    True
# 15  True  True    True

# %% [markdown]
# # value counts

# %% [markdown]
# ###  get the number of heart attack and non heart attack samples in the data
# * **use value_counts()**

# %%
## your code here
df['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %% [markdown]
# * **get their probabilites from the dataset**

# %%
## your code here
df['target'].value_counts(normalize=True)
# Out:
# target
# 1    0.544554
# 0    0.455446
# Name: proportion, dtype: float64

# %%
# to avoid any error
df['target'].value_counts() / df.shape[0]
# Out:
# target
# 1    0.544554
# 0    0.455446
# Name: count, dtype: float64

# %% [markdown]
# * ### get the probabilities of each gender of people with heart attack

# %%
## your code here
df.loc[df['target'] == 1,'sex'].value_counts(normalize=True)
# Out:
# sex
# 1    0.563636
# 0    0.436364
# Name: proportion, dtype: float64

# %% [markdown]
# * ### get the probabilities of heart vs no heart attack in the males

# %%
## your code here
df.loc[df['sex'] == 1,'target'].value_counts(normalize=True)
# Out:
# target
# 0    0.550725
# 1    0.449275
# Name: proportion, dtype: float64

# %% [markdown]
# # crosstab

# %%
table = pd.crosstab(df.sex, df.target)
table
# Out:
# target    0   1
# sex
# 0        24  72
# 1       114  93

# %% [markdown]
# * **rename target 1 to 'yes', and 0 to 'no'**
# * **rename gender 1 to 'male', and 0 to 'female'**

# %%
## your code here
table.rename(columns={0:'no',1:'yes'},inplace=True)
table.rename(index={0:'female',1:'male'},inplace=True)
table
# Out:
# target   no  yes
# sex
# female   24   72
# male    114   93

# %%
# or change the source data

df.loc[df['target'] == 1,'target'] = 'yes' # 1 -> yes
df.loc[df['target'] == 0,'target'] = 'no' # 0 -> no
df.loc[df['sex'] == 1,'sex'] = 'male' #1 -> male
df.loc[df['sex'] == 0,'sex'] = 'female' # 0 -> female


table = pd.crosstab(df.sex, df.target)
table
# Out:
# /tmp/ipython-input-1372289133.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'yes' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['target'] == 1,'target'] = 'yes' # 1 -> yes
# /tmp/ipython-input-1372289133.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'male' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['sex'] == 1,'sex'] = 'male' #1 -> male
# target   no  yes
# sex
# female   24   72
# male    114   93

# %% [markdown]
# * ## plot a stacked bar to visualize the gender vs attack

# %%
## your code here
from matplotlib import pyplot as plt


table.plot(kind='bar',stacked=True)
plt.title('gender vs attack')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# [Pandas Crosstab](https://pbpython.com/pandas-crosstab.html)

# %%
'''df = table[['age', 'target']][:3]
df'''
# Out:
# "df = table[['age', 'target']][:3]\ndf"

# %% [markdown]
# * ## rename column target by heart_attack

# %%
## your code here
df['heart_attack'] = df.pop('target')
df
# Out:
#      age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    male   3       145   233    1        0      150      0      2.3
# 1     37    male   2       130   250    0        1      187      0      3.5
# 2     41  female   1       130   204    0        0      172      0      1.4
# 3     56    male   1       120   236    0        1      178      0      0.8
# 4     57  female   0       120   354    0        1      163      1      0.6
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57  female   0       140   241    0        1      123      1      0.2
# 299   45    male   3       110   264    0        1      132      0      1.2
# 300   68    male   0       144   193    1        1      141      0      3.4
# 301   57    male   0       130   131    0        1      115      1      1.2
# 302   57  female   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal heart_attack
# 0        0   0     1          yes
# 1        0   0     2          yes
# 2        2   0     2          yes
# 3        2   0     2          yes
# 4        2   0     2          yes
# ..     ...  ..   ...          ...
# 298      1   0     3           no
# 299      1   0     3           no
# 300      1   2     3           no
# 301      1   1     3           no
# 302      1   1     2           no
#
# [303 rows x 14 columns]

# %%
table
# Out:
# target   no  yes
# sex
# female   24   72
# male    114   93

# %%
## transpose of the table

table.T
# Out:
# sex     female  male
# target
# no          24   114
# yes         72    93

# %% [markdown]
# # Addition

# %%
df1 = df[['age', 'heart_attack']][:3]
df2 = df[['age', 'heart_attack']][3:5]

# %%
df1
# Out:
#    age heart_attack
# 0   63          yes
# 1   37          yes
# 2   41          yes

# %%
df2
# Out:
#    age heart_attack
# 3   56          yes
# 4   57          yes

# %%
#Append
pd.concat([df1,df2])
# Out:
#    age heart_attack
# 0   63          yes
# 1   37          yes
# 2   41          yes
# 3   56          yes
# 4   57          yes

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------
# # Lab tasks
#
# ##### (1) fbs: The person's fasting blood sugar "fbs" (> 120 mg/dl, 1 = true; 0 = false)
#
# * create new column 'bloodSugar' with values 'Yes' if fbs=1 or 'No' if fbs=0

# %%
## your code here
df['bloodSugar'] = df['fbs'].apply(lambda x: 'Yes' if x == 1 else 'No')

df[['bloodSugar','fbs']]
# Out:
#     bloodSugar  fbs
# 0          Yes    1
# 1           No    0
# 2           No    0
# 3           No    0
# 4           No    0
# ..         ...  ...
# 298         No    0
# 299         No    0
# 300        Yes    1
# 301         No    0
# 302         No    0
#
# [303 rows x 2 columns]

# %% [markdown]
# ##### (2) cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# * convert chest pain column values to their corresponding meanings

# %%
df['cp'].unique()
# Out:
# array([3, 2, 1, 0])

# %%
## your code here
meanings = {0: 'typical angina', 1: 'atypical angina', 2: 'non-anginal pain', 3: 'asymptomatic'}
df['cp'] = df['cp'].map(meanings)
df['cp']
# Out:
# 0          asymptomatic
# 1      non-anginal pain
# 2       atypical angina
# 3       atypical angina
# 4        typical angina
#              ...
# 298      typical angina
# 299        asymptomatic
# 300      typical angina
# 301      typical angina
# 302     atypical angina
# Name: cp, Length: 303, dtype: object

# %% [markdown]
# ##### (3) crosstab: attack and bloodSugar cloumns VS. gender and chestPain cloumns

# %%
## your code here
table2 = pd.crosstab( index = [df['heart_attack'],df['bloodSugar']], columns = [df['sex'],df['cp']] , margins = True)
table2
# Out:
# sex                           female                                   \
# cp                      asymptomatic atypical angina non-anginal pain
# heart_attack bloodSugar
# no           No                    0               1                1
#              Yes                   0               1                0
# yes          No                    3              15               30
#              Yes                   1               1                4
# All                                4              18               35
#
# sex                                            male                  \
# cp                      typical angina asymptomatic atypical angina
# heart_attack bloodSugar
# no           No                     16            6               7
#              Yes                     5            1               0
# yes          No                     18            9              22
#              Yes                     0            3               3
# All                                 39           19              32
#
# sex                                                      All
# cp                      non-anginal pain typical angina
# heart_attack bloodSugar
# no           No                       14             71  116
#              Yes                       3             12   22
# yes          No                       25             20  142
#              Yes                      10              1   23
# All                                   52            104  303

# %% [markdown]
# ##### (4) Save the updated dataframe as a new csv file in a different directory

# %%
# It will saved in the same directory if the name only is given.
table2.to_csv('/content/drive/MyDrive/Lab1/updated_dataframe.csv' )
df.to_csv('/content/drive/MyDrive/Lab1/updated_dataset.csv' )

# %% [markdown]
# ##### (5) Count the number of patiens for each chestPain category

# %%
## your code here
df['cp'].value_counts()
# Out:
# cp
# typical angina      143
# non-anginal pain     87
# atypical angina      50
# asymptomatic         23
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    age   sex                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   63  male      asymptomatic       145   233    1        0      150      0
# 1   37  male  non-anginal pain       130   250    0        1      187      0
#
#    oldpeak  slope  ca  thal heart_attack bloodSugar
# 0      2.3      0   0     1          yes        Yes
# 1      3.5      0   0     2          yes         No

# %% [markdown]
# ##### (6) Create a new dataframe maunally that contains the fitst 2 rows in the heart.csv file. Rename it as new_df.

# %%
## your code here
data = {
    'age': [63, 37],
 'sex': ['male', 'male'],
 'cp': ['asymptomatic', 'non-anginal pain'],
 'trestbps': [145, 130],
 'chol': [233, 250],
 'fbs': [1, 0],
 'restecg': [0, 1],
 'thalach': [150, 187],
 'exang': [0, 0],
 'oldpeak': [2.3, 3.5],
 'slope': [0, 0],
 'ca': [0, 0],
 'thal': [1, 2],
 'heart_attack': ['yes', 'yes'],
 'bloodSugar': ['Yes', 'No']
}
new_df = pd.DataFrame(data)
new_df
# Out:
#    age   sex                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   63  male      asymptomatic       145   233    1        0      150      0
# 1   37  male  non-anginal pain       130   250    0        1      187      0
#
#    oldpeak  slope  ca  thal heart_attack bloodSugar
# 0      2.3      0   0     1          yes        Yes
# 1      3.5      0   0     2          yes         No
